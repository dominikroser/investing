# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import datetime as dt
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
from datetime import date
from datetime import date, timedelta
import yfinance as yf

# %%
def relative_strength(ticker_symbol):
    
    df = yf.download(ticker_symbol, start="2023-01-01", end= date.today())
    
    seven_months_ago = date.today() - timedelta(days=7*30)  # Approximating 30 days per month
    last_day_8_months_ago = seven_months_ago.replace(day=1) - timedelta(days=1) # Calculate the last day of the month 8 months ago
    closing_today = df['Close'].iloc[-1]
    df['Date'] = df.index
    
    specific_date = last_day_8_months_ago.strftime('%Y-%m-%d')
    closing_price_8months = df.loc[df['Date'] == specific_date, 'Close'].values
    
    
    percentage_change = ((closing_today - closing_price_8months) / closing_price_8months) * 100
    
    print("Closing price today:", closing_today)
    print("Closing price 8 months ago:", closing_price_8months)
    print("Percentage change in 8 months:", percentage_change)

# %%
relative_strength('FSPTX')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Closing price today: 29.700000762939453
# Closing price 8 months ago: [26.79999924]
# Percentage change in 8 months: [10.82090152]

# %%
# Define the ticker symbol
ticker_symbol = 'FSPTX'
ticker_symbol1 = 'FBMPX'
ticker_symbol2 = 'FSENX'
ticker_symbol3 = 'FDFAX'
ticker_symbol4 = 'CASHX'

# Fetch historical market data
fsptx_data = yf.download(ticker_symbol, start="2023-01-01", end= date.today())
fbmpx_data = yf.download(ticker_symbol1, start="2020-01-01", end= date.today())
fsenx_data = yf.download(ticker_symbol2, start="2020-01-01", end= date.today())
fdfax_data = yf.download(ticker_symbol3, start="2020-01-01", end= date.today())
cashx_data = yf.download(ticker_symbol4, start="2020-01-01", end= date.today())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['CASHX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2020-01-01 -> 2024-04-23)')

# %%
# Calculate the date 8 months ago
seven_months_ago = date.today() - timedelta(days=7*30)  # Approximating 30 days per month

# %%
# Calculate the last day of the month 8 months ago
last_day_8_months_ago = seven_months_ago.replace(day=1) - timedelta(days=1)

# %%
last_day_8_months_ago
# Out:
# datetime.date(2023, 8, 31)

# %%
# Extract closing price of today
closing_today = fsptx_data['Close'].iloc[-1]

# %%
date.today()
# Out:
# datetime.date(2024, 4, 22)

# %%
fsptx_data['Date'] = fsptx_data.index

# %%
fsptx_data
# Out:
#                  Open       High        Low      Close  Adj Close  Volume  \
# Date
# 2023-01-03  17.620001  17.620001  17.620001  17.620001  17.617590       0
# 2023-01-04  17.730000  17.730000  17.730000  17.730000  17.727573       0
# 2023-01-05  17.290001  17.290001  17.290001  17.290001  17.287634       0
# 2023-01-06  17.780001  17.780001  17.780001  17.780001  17.777567       0
# 2023-01-09  18.100000  18.100000  18.100000  18.100000  18.097523       0
# ...               ...        ...        ...        ...        ...     ...
# 2024-04-16  31.120001  31.120001  31.120001  31.120001  31.120001       0
# 2024-04-17  30.629999  30.629999  30.629999  30.629999  30.629999       0
# 2024-04-18  30.379999  30.379999  30.379999  30.379999  30.379999       0
# 2024-04-19  29.280001  29.280001  29.280001  29.280001  29.280001       0
# 2024-04-22  29.700001  29.700001  29.700001  29.700001  29.700001       0
#
#                  Date
# Date
# 2023-01-03 2023-01-03
# ...

# %%
specific_date = last_day_8_months_ago.strftime('%Y-%m-%d')
closing_price_8months = fsptx_data.loc[fsptx_data['Date'] == specific_date, 'Close'].values

# %%
# Calculate the percentage change
percentage_change = ((closing_today - closing_price_8months) / closing_price_8months) * 100

print("Closing price today:", closing_today)
print("Closing price 8 months ago:", closing_price_8months)
print("Percentage change in 8 months:", percentage_change)
# Out:
# Closing price today: 29.700000762939453
# Closing price 8 months ago: [26.79999924]
# Percentage change in 8 months: [10.82090152]

# %%
closing_price_specific_date
# Out:
# array([26.79999924])

# %%
# Extract closing price of 8 months ago
closing_8_months_ago = fsptx_data.loc[eight_months_ago.strftime('%Y-%m-%d'), 'Close']
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "pandas\_libs\index.pyx", line 548, in pandas._libs.index.DatetimeEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 2263, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 2273, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 1693094400000000000
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\roser\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py", line 3802, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 516, in pandas._libs.index.DatetimeEngine.get_loc
#   File "pandas\_libs\index.pyx", line 550, in pandas._libs.index.DatetimeEngine.get_loc
# KeyError: Timestamp('2023-08-27 00:00:00')
#
# ...

# %%
# Out:
# dtype('float64')

# %%
# Extract closing price of 8 months ago
closing_8_months_ago = fsptx_data(Date['2024-04-22'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Extract closing price of 8 months ago
# ----> 2 closing_8_months_ago = fsptx_data(Date['2024-04-22'])
#
# NameError: name 'Date' is not defined

# %%
# Extract closing price of 8 months ago
closing_8_months_ago = fsptx_data.loc[eight_months_ago.strftime('%Y-%m-%d'), 'Close']
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "pandas\_libs\index.pyx", line 548, in pandas._libs.index.DatetimeEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 2263, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 2273, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 1693094400000000000
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\roser\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py", line 3802, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 516, in pandas._libs.index.DatetimeEngine.get_loc
#   File "pandas\_libs\index.pyx", line 550, in pandas._libs.index.DatetimeEngine.get_loc
# KeyError: Timestamp('2023-08-27 00:00:00')
#
# ...

# %%
# Calculate the percentage change
percentage_change = ((closing_today - closing_8_months_ago) / closing_8_months_ago) * 100

print("Closing price today:", closing_today)
print("Closing price 8 months ago:", closing_8_months_ago)
print("Percentage change in 8 months:", percentage_change)

# %%
tesla_data.to_csv('tesla_data.csv')

# %%
tesla_data.plot()
plt.show()

# %%
tesla_data['Adj Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
tesla_data['Close'].plot()
# Out:
# <Axes: xlabel='Date'>
